# %%
queue = []
# Enqueue
queue.append("A")
queue.append("B")
print("Queue after Enqueue:", queue)

# Dequeue
queue.pop(0)
print("Queue after Dequeue:", queue)
# Out:
# Queue after Enqueue: ['A', 'B']
# Queue after Dequeue: ['B']
